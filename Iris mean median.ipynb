# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 145  146            6.7           3.0            5.2           2.3  \
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes.value_counts()
# Out:
# float64    4
# int64      1
# object     1
# Name: count, dtype: int64

# %%
df.groupby('Species').SepalLengthCm.agg(['min', 'max', 'mean', 'median', 'std', 'var'])
# Out:
#                  min  max   mean  median       std       var
# Species
# Iris-setosa      4.3  5.8  5.006     5.0  0.352490  0.124249
# Iris-versicolor  4.9  7.0  5.936     5.9  0.516171  0.266433
# Iris-virginica   4.9  7.9  6.588     6.5  0.635880  0.404343

# %%
df.groupby('Species').PetalLengthCm.agg(['min', 'max', 'mean', 'median', 'std' ,'var'])
# Out:
#                  min  max   mean  median       std       var
# Species
# Iris-setosa      1.0  1.9  1.464    1.50  0.173511  0.030106
# Iris-versicolor  3.0  5.1  4.260    4.35  0.469911  0.220816
# Iris-virginica   4.5  6.9  5.552    5.55  0.551895  0.304588

# %%
df.groupby('Species').SepalWidthCm.agg(['min', 'max', 'mean', 'median', 'std', 'var'])
# Out:
#                  min  max   mean  median       std       var
# Species
# Iris-setosa      2.3  4.4  3.418     3.4  0.381024  0.145180
# Iris-versicolor  2.0  3.4  2.770     2.8  0.313798  0.098469
# Iris-virginica   2.2  3.8  2.974     3.0  0.322497  0.104004

# %%
df.groupby('Species').PetalWidthCm.agg(['min', 'max', 'mean', 'median', 'std', 'var'])
# Out:
#                  min  max   mean  median       std       var
# Species
# Iris-setosa      0.1  0.6  0.244     0.2  0.107210  0.011494
# Iris-versicolor  1.0  1.8  1.326     1.3  0.197753  0.039106
# Iris-virginica   1.4  2.5  2.026     2.0  0.274650  0.075433

# %%
# Group by 'Species' and calculate mean for numeric variables
mean_values = df.groupby('Species').mean()

# Plot bar plot for mean values
mean_values.plot(kind='bar', figsize=(10, 6))
plt.title('Mean Values of Numeric Variables by Species')
plt.xlabel('Species')
plt.ylabel('Mean Value')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Numeric Variable')
plt.show()

# %%
# Plotting SD

# Group by 'Species' and calculate standard deviation for numeric variables
std_values = df.groupby('Species').std()

# Plot bar plot for standard deviation values
std_values.plot(kind='bar', figsize=(10, 6))
plt.title('Standard Deviation of Numeric Variables by Species')
plt.xlabel('Species')
plt.ylabel('Standard Deviation')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Numeric Variable')
plt.show()

# %%
# Plotting Median 

# Group by 'Species' and calculate median for numeric variables
median_values = df.groupby('Species').median()

# Plot bar plot for median values
median_values.plot(kind='bar', figsize=(10, 6))
plt.title('Median of Numeric Variables by Species')
plt.xlabel('Species')
plt.ylabel('Median')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Numeric Variable')
plt.show()

# %%
# Ploting Min 
# Group by 'Species' and calculate minimum values for numeric variables
min_values = df.groupby('Species').min()

# Plot bar plot for minimum values
min_values.plot(kind='bar', figsize=(10, 6))
plt.title('Minimum Values of Numeric Variables by Species')
plt.xlabel('Species')
plt.ylabel('Minimum Value')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Numeric Variable')
plt.show()

# %%
# Plotting Max 
# Group by 'Species' and calculate maximum values for numeric variables
max_values = df.groupby('Species').max()

# Plot bar plot for maximum values
max_values.plot(kind='bar', figsize=(10, 6))
plt.title('Maximum Values of Numeric Variables by Species')
plt.xlabel('Species')
plt.ylabel('Maximum Value')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Numeric Variable')
plt.show()
