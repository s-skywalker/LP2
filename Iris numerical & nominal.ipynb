# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris_df = pd.read_csv(url, names=column_names)

print(iris_df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print("Features and their types : ")
print(iris_df.dtypes)
# Out:
# Features and their types :
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class            object
# dtype: object

# %%
iris_df.hist(figsize = (10, 8))
plt.suptitle("Histograms of the features in Iris Dataset")
# Out:
# Text(0.5, 0.98, 'Histograms of the features in Iris Dataset')

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = iris_df)
plt.title("Boxplots of Features in Iris Dataset")
# Out:
# Text(0.5, 1.0, 'Boxplots of Features in Iris Dataset')

# %%
plt.figure(figsize=(12, 8))
for i, feature in enumerate(iris_df.columns[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x="class", y=feature, data=iris_df)
    plt.title(f"Boxplot of {feature}")
plt.tight_layout()
plt.show()
